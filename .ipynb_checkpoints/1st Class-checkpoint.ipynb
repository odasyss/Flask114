# %%
print("hello world")
# Out:
# hello world

# %%
name = input('What is your name?\n')
print ('Hi, %s.' % name)
# Out:
# What is your name?
# odasys
# Hi, odasys.

# %%
for letter in "hello, world!":
    print(letter)
# Out:
# h
# e
# l
# l
# o
# ,
#
# w
# o
# r
# l
# d
# !
