# %%
class Queue:
    def __init__(self):
        self.items = []
    def is_empty(self):
        return self.items == []
    def enqueue(self, item):
        self.items.insert(0, item)
    def dequeue(self):
        return self.items.pop()
    def size(self):
        return len(self.items)

# %%
from string import ascii_lowercase
from random import randint, choice
from time import sleep

def register_visitor(visitor_queue):
    for char in ascii_lowercase:
        visitor_queue.enqueue(char)
        
        
def service_customer(visitor_queue):
    bank_tellers = ["A","B","C","D","E","F","G"]
    while not visitor_queue.is_empty():
        visitor = visitor_queue.dequeue()
        print("thank you for waiting %s, station %s is ready for you." % (visitor, choice(bank_tellers)) )
        sleep(randint(1,2))
#     print("Empty visitor queue")

def main():
    visitor_queue = Queue()
    register_visitor(visitor_queue)
    service_customer(visitor_queue)

# %%
main()
# Out:
# thank you for waiting a, station G is ready for you.
# thank you for waiting b, station B is ready for you.
# thank you for waiting c, station C is ready for you.
# thank you for waiting d, station C is ready for you.
# thank you for waiting e, station C is ready for you.
# thank you for waiting f, station C is ready for you.
# thank you for waiting g, station D is ready for you.
# thank you for waiting h, station C is ready for you.
# thank you for waiting i, station A is ready for you.
# thank you for waiting j, station B is ready for you.
# thank you for waiting k, station F is ready for you.
# thank you for waiting l, station D is ready for you.
# thank you for waiting m, station F is ready for you.
# thank you for waiting n, station G is ready for you.
# thank you for waiting o, station G is ready for you.
# thank you for waiting p, station F is ready for you.
# thank you for waiting q, station D is ready for you.
# thank you for waiting r, station D is ready for you.
# thank you for waiting s, station D is ready for you.
# thank you for waiting t, station G is ready for you.
# thank you for waiting u, station G is ready for you.
# thank you for waiting v, station B is ready for you.
# thank you for waiting w, station F is ready for you.
# thank you for waiting x, station A is ready for you.
# thank you for waiting y, station E is ready for you.
# thank you for waiting z, station B is ready for you.

# %% [markdown]
# # Given a string of opening and closing parenthesis, check whether its balanced. We have 3 types of parentheses:round brackets:()

# %% [markdown]
#  # base case: length must be even
#
#  # take an empty stack of characters
#
#
# # if bracket is opening brace, push it into the stack

# %%
from collections import stack
def balance_check(s):
    stack = Stack()
    opening - set('({[')
    matches = set([{"(",")"}, ("[","]"), ("{","}")])
    for paren in s:
        if paren in opening:
            stack.push(paren)
        else:
            if stack.is_empty():
                return False
            last_open = stack.pop()
            if(last_open, paren) not in matches:
                return False
        return stack.is_empty()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-31-04eba8b93501> in <module>
# ----> 1 from collections import stack
#       2 def balance_check(s):
#       3     stack = Stack()
#       4     opening - set('({[')
#       5     matches = set([{"(",")"}, ("[","]"), ("{","}")])
#
# ImportError: cannot import name 'stack'

# %%
balance_check("([{}])")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-3a18e5fe4a7d> in <module>
# ----> 1 balance_check("([{}])")
#
# <ipython-input-23-f877ac15624c> in balance_check(s)
#       1 def balance_check(s):
# ----> 2     stack = Dequeue()
#       3     opening - set('({[')
#       4     matches = set([{"(",")"}, ("[","]"), ("{","}")])
#       5     for paren in s:
#
# NameError: name 'Dequeue' is not defined

# %%
class Queue2Stacks:
    def __init__(self):
        self.stack1 = []
        self.stack2 = []
        
    def enqueue(self, element):
        pass
    
    def dequeue(self):
        pass
    
    def test():
#         this should print 0,1,2,3,4
# Note
        q = Queue2Stacks()
        for i in range(5):
            q.enqueue(i)
        for i in range(5):
            print(q.dequeue())
